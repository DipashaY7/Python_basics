# %% [markdown]
# <a href="https://colab.research.google.com/github/DipashaY7/Python_basics/blob/main/Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Bike:
    name = "Duke"
    gear = 2

bike1 = Bike()

print("Bike Name:", bike1.name)
print("Gear:", bike1.gear)
# Out:
# Bike Name: Duke
# Gear: 2

# %%
#@ Delete an object
# use a keyword del

del p1

# %%
#@ To create multiple object of same class

p1 = MyClass()
p2 = MyClass()
p3 = MyClass()

p1.x, p2.x, p3.x

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print("Hello and Namaste! This is " + self.name)

person1 = Person("Dipasha", 21)
person1.greet()
# Out:
# Hello and Namaste! This is Dipasha

# %%
#@ Task- 2
class Car:
    def __init__(self, brand):
        self.brand = brand

    def show(self):
        print("The brand is " + self.brand)

c1 = Car("BYD")
c1.show()
# Out:
# The brand is BYD

# %% [markdown]
# ## Class Properties

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print("Hello and Namaste! This is " + self.name)

# %%
p1 = Person("Dipasha", 21)
print(p1.name)
print(p1.age)
# Out:
# Dipasha
# 21

# %%
#@ modify the properties

p1.age = 22
print(p1.age)
# Out:
# 22

# %%
#@ Delete the age property

del(p1.age)

# %%
print(p1.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_592/1928080736.py in <cell line: 0>()
# ----> 1 print(p1.age)
#
# AttributeError: 'Person' object has no attribute 'age'

# %% [markdown]
# ### Class properties vs Object Properties
# - properties defined inside init belong to each object (instance properties)
#
# -properties defined outside methods belong to a class itself(class properties) and is shared by all the objects.

# %%
#@ Example
class Person:
    species = "Human"
    def __init__(self, name, age):
        self.name = name

p1 = Person("Dipasha", 21)
p1.species = "Dog"

# %%
#@ try to modify the class property

class Person:
    lastname = "thapa"
    def __init__(self, name, age):
        self.name = name

Person.lastname = "Tamang"
p1 = Person("Dipasha", 21)
print(p1.lastname)
# Out:
# Tamang

# %%
#@ Add a new property

class Person:
    def __init__(self, name):
        self.name = name

p1 = Person("Dipasha")

p1.age = 21
p1.address = "Kathmandu"

p1.name, p1.age, p1.address
# Out:
# ('Dipasha', 21, 'Kathmandu')

# %%
#@ Methods

class Person:
    def __init__(self, name):
      self.name = name

    def greet(self):
        print("Hello sir, I am " + self.name)

p1 = Person("Dipasha")
p1.greet()
# Out:
# Hello sir, I am Dipasha

# %%
#@ Task - 3

class Calculator:
    def __init__(self, a , b):
      self.a = a
      self.b = b

    def add(self):
        print ("The addition is ", self.a+self.b)

    def multiply(self):
        print ("The multiplication is ", self.a*self.b)

    def divide(self):
        print ("The division is ", self.a/self.b)

    def subtraction(self):
        print ("The subtraction is ", self.a-self.b)

c1 = Calculator(10, 5)

c1.add()
c1.multiply()
c1.divide()
c1.subtraction()
# Out:
# The addition is  15
# The multiplication is  50
# The division is  2.0
# The subtraction is  5

# %% [markdown]
# # Multiple Methods
# - A class can have multiple methods that work together.

# %%
class Playlist:
    def __init__(self, name):
        self.name = name
        self.songs = []

    def add_song(self, song):
        self.songs.append(song)
        print(f"Added a song: {song}")


    def remove_song(self, song):
        if song in self.songs:
            self.songs.remove(song)
            print(f"Removed a song: {song}")

    def show_songs(self):
        print(f"Songs in the playlist: {self.name}")
        for song in self.songs:
            print(song)

my_playlist = Playlist("Favourites")
my_playlist.add_song("Song 1")
my_playlist.add_song("Song 2")
my_playlist.add_song("Song 3")

my_playlist.remove_song("Song 2")
my_playlist.show_songs()
# Out:
# Added a song: Song 1
# Added a song: Song 2
# Added a song: Song 3
# Removed a song: Song 2
# Songs in the playlist: Favourites
# Song 1
# Song 3

# %% [markdown]
# # Inheritance in Python

# %% [markdown]
# Inheritance allows us to define a class that inherits all the methods and properties from another class
#
# -**Parent class** : Class being inherited from, also call it as base class
# -**Child class** : Class that inherits from another class, also call it as derived class

# %%
#@ Create a Parent class
## Any class

# %%
class Person:
    def __init__(self, fname, lnname):
        self.firstname = fname
        self.lastname = lnname

    def printname(self):
        print(self.firstname, self.lastname)

person1 = Person("Dipasha", "Tamang")
person1.printname()
# Out:
# Dipasha Tamang

# %%
person2 = Person("Dipika", "Dulaal")
person2.printname()
# Out:
# Dipika Dulaal

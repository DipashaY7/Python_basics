# %% [markdown]
# <a href="https://colab.research.google.com/github/DipashaY7/Python_basics/blob/main/Polymorphism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Single Inheritance

class Parent:
    def func1(self):
        print("This function is parent class")

class Child(Parent):
    def func2(self):
        print("This function is child class")

o1 = Child()
o1.func1()
o1.func2()
# Out:
# This function is parent class
# This function is child class

# %%
# Multiple Inheritance

class Mother:
    mothername = ""

    def mother(self):
        print(self.mothername)

class Father:
    fathername = ""

    def father(self):
        print(self.fathername)

class Son(Mother, Father):
    def parents(self):
        print("Father :", self.fathername)
        print("Mother :", self.mothername)

s1 = Son()
s1.fathername = "Rajesh"
s1.mothername = "Sita"
s1.parents()
# Out:
# Father : Rajesh
# Mother : Sita

# %%
# multi-level Inheritance

class Grandfather:
    def __init__(self, grandfathername):
        self.grandfathername = grandfathername

class Father(Grandfather):
    def __init__(self, fathername, grandfathername):
        self.fathername = fathername
        Grandfather.__init__(self, grandfathername)

class Son(Father):
    def __init__(self, sonname, fathername, grandfathername):
        self.sonname = sonname
        Father.__init__(self, fathername, grandfathername)

    def print_name(self):
        print('Grandfather name :', self.grandfathername)
        print("Father name :", self.fathername)
        print("Son name :", self.sonname)

s1 = Son("Levi", "Eren", "Armin")
s1.print_name()
# Out:
# Grandfather name : Armin
# Father name : Eren
# Son name : Levi

# %% [markdown]
# Important Notes:
# -Son inherits from Father and Father inherits from Grandfather
# -Each constructor passes values up to the

# %%
# Hierarchical Inheritance

class Parent:
    def func1(self):
        print("This function is in parent class")

class Child1(Parent):
    def func2(self):
        print("This function is in child1")

class Child2(Parent):
    def func3(self):
        print("This function is in child2")

o1 = Child1()
o2 = Child2()

o1.func1()
o1.func2()

o2.func1()
o2.func3()
# Out:
# This function is in parent class
# This function is in child1
# This function is in parent class
# This function is in child2

# %%
# Hybrid Inheritance

class Father():
    def __init__(self, fathername):
        self.fathername = fathername

class Child1(Father):
    def __init__(self, child1name, fathername):
        self.child1name = child1name
        Father.__init__(self, fathername)

class Child2(Father):
    def __init__(self, child2name, fathername):
        self.child2name = child2name
        self.fathername = fathername

class Grandchild(Child1, Child2):
    def __init__(self, grandchildname, child1name, child2name, fathername):
        self.grandchildname = grandchildname
        Child1.__init__(self, child1name, fathername)
        Child2.__init__(self, child2name, fathername)

    def print_name(self):
        print("Fathername: ", self.fathername)
        print("Child1name: ", self.child1name)
        print("Child2name: ", self.child2name)
        print("Grandchildname: ", self.grandchildname)

g1 = Grandchild("Prem", "Dipasha", "Pradik", "Diyank")
g1.print_name()
# Out:
# Fathername:  Diyank
# Child1name:  Dipasha
# Child2name:  Pradik
# Grandchildname:  Prem

# %%
#@ Animal

#Parent class

class Animal:
  def __init__(self, name):
    self.name = name

  def info(self):
      print("Animal name:", self.name)

#Child Class
class Dog(Animal):
    def __init__(self, name, breed):
    #Call constructor based upon python's method resolution order(MRO)
      super().__init__(name)
      self.breed = breed

    def details(self):
        print(self.name, "is a", self.breed)

d = Dog("Khaire", "Bhusiya")
d.details()
# Out:
# Khaire is a Bhusiya

# %% [markdown]
# # Polymorphism
# -Method Overloading
# In python the real compile time polymorphism (overloading) doesn't support. why?
# -It is because the same behaviour can be achieved by using variable length argument(*args, **kwargs)
#
#   add(a, b)
#
#   add(a, b, c)
#
# -selecting a method or operation in a compile time
# -Method Overriding

# %%
# Polymorphism

#@ Example
class Calculator:
    def multiply(self, a=7 , b=5, *args):
        result =

# %%
#@ Overriding

class Animal:
    def sound(self):
        return "Some generic sound"

class Dog(Animal):
    def sound(self):
        return "Woof"

class Cat(Animal):
    def sound(self):
        return "Meow"

animals = [Dog(), Cat(), Animal()]
for animal in animals:
    print(animal.sound())
# Out:
# Woof
# Meow
# Some generic sound

# %%
# Task - 1

class Shape:
    def area(self):
        print("Area of the Shape")


class Rectangle:
    def __init__(self, width, length):
        self.width = width
        self.length = length

    def area(self):
        print("Area of the Rectangle:", self.width * self.length)


class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        print("Area of the Circle:", 3.14 * self.radius * self.radius)

shape = Shape()
rectangle = Rectangle(10, 5)
circle = Circle(7)

shape.area()
rectangle.area()
circle.area()
